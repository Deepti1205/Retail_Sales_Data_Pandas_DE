# %% [markdown]
# #**Problem Statement**
#
#
# Build an ETL pipeline to:
#
# *  Extract sales data across stores and departments.
# *  Transform: clean data, handle nulls, derive profits, and aggregate metrics.
# *  Load: save cleaned/aggregated results to .csv or .sqlite.
# *  Bonus: Visualize top stores, trends, etc.

# %% [markdown]
# #**EXTRACT**

# %%
# Standard Imports
import pandas as pd
import os
import glob

# %%
# Load all csvs
data_path = "data/*.csv"
data_path

csv_files = glob.glob(data_path)
csv_files
# Out:
# ['data/sales_data_set.csv',
#  'data/features_data_set.csv',
#  'data/stores_data_set.csv']

# %%
dfs ={}
for file in csv_files:
  key = os.path.basename(file).split('.')[0]
  print(key)
# Out:
# sales_data_set
# features_data_set
# stores_data_set

# %%
dfs ={}
for file in csv_files:
  key = os.path.basename(file).split('.')[0]
  dfs[key] = pd.read_csv(file)

# %%
dfs  # key : value pair - > csv name : dataset
# Out:
# {'sales_data_set':         Store  Dept        Date  Weekly_Sales  IsHoliday
#  0           1     1  05/02/2010      24924.50      False
#  1           1     1  12/02/2010      46039.49       True
#  2           1     1  19/02/2010      41595.55      False
#  3           1     1  26/02/2010      19403.54      False
#  4           1     1  05/03/2010      21827.90      False
#  ...       ...   ...         ...           ...        ...
#  421565     45    98  28/09/2012        508.37      False
#  421566     45    98  05/10/2012        628.10      False
#  421567     45    98  12/10/2012       1061.02      False
#  421568     45    98  19/10/2012        760.01      False
#  421569     45    98  26/10/2012       1076.80      False
#
#  [421570 rows x 5 columns],
#  'features_data_set':       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
#  0         1  05/02/2010        42.31       2.572        NaN        NaN
#  1         1  12/02/2010        38.51       2.548        NaN        NaN
#  2         1  19/02/2010        39.93       2.514        NaN        NaN
#  3         1  26/02/2010        46.63       2.561        NaN        NaN
#  4         1  05/03/2010        46.50       2.625        NaN        NaN
#  ...     ...         ...          ...         ...        ...        ...
#  8185     45  28/06/2013        76.05       3.639    4842.29     975.03
#  8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
#  8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
#  8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
#  8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#        MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
#  0           NaN        NaN        NaN  211.096358         8.106      False
#  1           NaN        NaN        NaN  211.242170         8.106       True
#  2           NaN        NaN        NaN  211.289143         8.106      False
#  3           NaN        NaN        NaN  211.319643         8.106      False
#  4           NaN        NaN        NaN  211.350143         8.106      False
#  ...         ...        ...        ...         ...           ...        ...
#  8185       3.00    2449.97    3169.69         NaN           NaN      False
#  8186     582.74    5797.47    1514.93         NaN           NaN      False
#  8187      85.72     744.84    2150.36         NaN           NaN      False
#  8188     204.19     363.00    1059.46         NaN           NaN      False
#  8189       2.06      10.88    1864.57         NaN           NaN      False
#
#  [8190 rows x 12 columns],
#  'stores_data_set':     Store Type    Size
#  0       1    A  151315
#  1       2    A  202307
#  2       3    B   37392
#  3       4    A  205863
#  4       5    B   34875
#  5       6    A  202505
#  6       7    B   70713
#  7       8    A  155078
#  8       9    B  125833
#  9      10    B  126512
#  10     11    A  207499
#  11     12    B  112238
#  12     13    A  219622
#  13     14    A  200898
#  14     15    B  123737
#  15     16    B   57197
#  16     17    B   93188
#  17     18    B  120653
#  18     19    A  203819
#  19     20    A  203742
#  20     21    B  140167
#  21     22    B  119557
#  22     23    B  114533
#  23     24    A  203819
#  24     25    B  128107
#  25     26    A  152513
#  26     27    A  204184
#  27     28    A  206302
#  28     29    B   93638
#  29     30    C   42988
#  30     31    A  203750
#  31     32    A  203007
#  32     33    A   39690
#  33     34    A  158114
#  34     35    B  103681
#  35     36    A   39910
#  36     37    C   39910
#  37     38    C   39690
#  38     39    A  184109
#  39     40    A  155083
#  40     41    A  196321
#  41     42    C   39690
#  42     43    C   41062
#  43     44    C   39910
#  44     45    B  118221}

# %%
type(dfs)
# Out:
# dict

# %%
#To divide each csvs in different datasets
sales = dfs['sales_data_set']
stores = dfs['stores_data_set']
features = dfs['features_data_set']

# %%
sales
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
type(sales) , type(stores), type(features)
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame)

# %% [markdown]
# #**TRANSFORM**

# %% [markdown]
# **1. Standardize Column Names**

# %%
for df in [sales,stores,features]:
  df.columns = df.columns.str.lower().str.strip()

# %%
sales.head()
# Out:
#    store  dept        date  weekly_sales  isholiday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
stores.head()
# Out:
#    store type    size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
features.head()
# Out:
#    store        date  temperature  fuel_price  markdown1  markdown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    markdown3  markdown4  markdown5         cpi  unemployment  isholiday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %% [markdown]
# **2. Convert Dates dtype to datetime**

# %%
sales['date'] = pd.to_datetime(sales['date'], format="%d/%m/%Y")
features['date'] = pd.to_datetime(features['date'], format = "%d/%m/%Y")

# %%
sales.head()
# Out:
#    store  dept       date  weekly_sales  isholiday
# 0      1     1 2010-02-05      24924.50      False
# 1      1     1 2010-02-12      46039.49       True
# 2      1     1 2010-02-19      41595.55      False
# 3      1     1 2010-02-26      19403.54      False
# 4      1     1 2010-03-05      21827.90      False

# %%
features.head()
# Out:
#    store       date  temperature  fuel_price  markdown1  markdown2  markdown3  \
# 0      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-02-12        38.51       2.548        NaN        NaN        NaN
# 2      1 2010-02-19        39.93       2.514        NaN        NaN        NaN
# 3      1 2010-02-26        46.63       2.561        NaN        NaN        NaN
# 4      1 2010-03-05        46.50       2.625        NaN        NaN        NaN
#
#    markdown4  markdown5         cpi  unemployment  isholiday
# 0        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN  211.350143         8.106      False

# %% [markdown]
# **3. Merge DataFrames**

# %%
df = sales.merge(stores,on='store',how='left')
df_full = features.merge(df,on=['store','date'],how='left')

# %%
df_full.head()
# Out:
#    store       date  temperature  fuel_price  markdown1  markdown2  markdown3  \
# 0      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 2      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 3      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 4      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
#
#    markdown4  markdown5         cpi  unemployment  isholiday_x  dept  \
# 0        NaN        NaN  211.096358         8.106        False   1.0
# 1        NaN        NaN  211.096358         8.106        False   2.0
# 2        NaN        NaN  211.096358         8.106        False   3.0
# 3        NaN        NaN  211.096358         8.106        False   4.0
# 4        NaN        NaN  211.096358         8.106        False   5.0
#
#    weekly_sales isholiday_y type      size
# 0      24924.50       False    A  151315.0
# 1      50605.27       False    A  151315.0
# 2      13740.12       False    A  151315.0
# 3      39954.04       False    A  151315.0
# 4      32229.38       False    A  151315.0

# %% [markdown]
# **4. Handle Missing Values**

# %%
df_full.isna().sum()
# Out:
# store                0
# date                 0
# temperature          0
# fuel_price           0
# markdown1       270892
# markdown2       310793
# markdown3       284667
# markdown4       286859
# markdown5       270138
# cpi                585
# unemployment       585
# isholiday_x          0
# dept              1755
# weekly_sales      1755
# isholiday_y       1755
# type              1755
# size              1755
# dtype: int64

# %%
df_full.fillna(df_full.median(numeric_only=True),inplace=True)

# %%
df_full.isna().sum()
# Out:
# store              0
# date               0
# temperature        0
# fuel_price         0
# markdown1          0
# markdown2          0
# markdown3          0
# markdown4          0
# markdown5          0
# cpi                0
# unemployment       0
# isholiday_x        0
# dept               0
# weekly_sales       0
# isholiday_y     1755
# type            1755
# size               0
# dtype: int64

# %%
df_full.head()
# Out:
#    store       date  temperature  fuel_price  markdown1  markdown2  markdown3  \
# 0      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 1      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 2      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 3      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 4      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
#
#    markdown4  markdown5         cpi  unemployment  isholiday_x  dept  \
# 0    1465.54    3340.02  211.096358         8.106        False   1.0
# 1    1465.54    3340.02  211.096358         8.106        False   2.0
# 2    1465.54    3340.02  211.096358         8.106        False   3.0
# 3    1465.54    3340.02  211.096358         8.106        False   4.0
# 4    1465.54    3340.02  211.096358         8.106        False   5.0
#
#    weekly_sales isholiday_y type      size
# 0      24924.50       False    A  151315.0
# 1      50605.27       False    A  151315.0
# 2      13740.12       False    A  151315.0
# 3      39954.04       False    A  151315.0
# 4      32229.38       False    A  151315.0

# %% [markdown]
# **5. Add Derived Columns**
#
# Assuming columns: weekly_sales, unit_cost, units_sold

# %%
# Example: Add estimated cost and profit
df_full['revenue'] = df_full['weekly_sales']
df_full['cost'] = df_full['weekly_sales'] * .70 # Use avg if not present
df_full['profit'] = df_full['weekly_sales'] - df_full['cost']

# %%
df_full.head()
# Out:
#    store       date  temperature  fuel_price  markdown1  markdown2  markdown3  \
# 0      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 1      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 2      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 3      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
# 4      1 2010-02-05        42.31       2.572    5336.52     194.67      24.83
#
#    markdown4  markdown5         cpi  unemployment  isholiday_x  dept  \
# 0    1465.54    3340.02  211.096358         8.106        False   1.0
# 1    1465.54    3340.02  211.096358         8.106        False   2.0
# 2    1465.54    3340.02  211.096358         8.106        False   3.0
# 3    1465.54    3340.02  211.096358         8.106        False   4.0
# 4    1465.54    3340.02  211.096358         8.106        False   5.0
#
#    weekly_sales isholiday_y type      size   revenue       cost     profit
# 0      24924.50       False    A  151315.0  24924.50  17447.150   7477.350
# 1      50605.27       False    A  151315.0  50605.27  35423.689  15181.581
# 2      13740.12       False    A  151315.0  13740.12   9618.084   4122.036
# 3      39954.04       False    A  151315.0  39954.04  27967.828  11986.212
# 4      32229.38       False    A  151315.0  32229.38  22560.566   9668.814

# %% [markdown]
# **6. Aggregation by Store/Dept/Month**

# %%
df_full['month'] = df_full['date'].dt.to_period('M')
df_full
# Out:
#         store       date  temperature  fuel_price  markdown1  markdown2  \
# 0           1 2010-02-05        42.31       2.572    5336.52     194.67
# 1           1 2010-02-05        42.31       2.572    5336.52     194.67
# 2           1 2010-02-05        42.31       2.572    5336.52     194.67
# 3           1 2010-02-05        42.31       2.572    5336.52     194.67
# 4           1 2010-02-05        42.31       2.572    5336.52     194.67
# ...       ...        ...          ...         ...        ...        ...
# 423320     45 2013-06-28        76.05       3.639    4842.29     975.03
# 423321     45 2013-07-05        77.50       3.614    9090.48    2268.58
# 423322     45 2013-07-12        79.37       3.614    3789.94    1827.31
# 423323     45 2013-07-19        82.84       3.737    2961.49    1047.07
# 423324     45 2013-07-26        76.06       3.804     212.02     851.73
#
#         markdown3  markdown4  markdown5         cpi  ...  isholiday_x  dept  \
# 0           24.83    1465.54    3340.02  211.096358  ...        False   1.0
# 1           24.83    1465.54    3340.02  211.096358  ...        False   2.0
# 2           24.83    1465.54    3340.02  211.096358  ...        False   3.0
# 3           24.83    1465.54    3340.02  211.096358  ...        False   4.0
# 4           24.83    1465.54    3340.02  211.096358  ...        False   5.0
# ...           ...        ...        ...         ...  ...          ...   ...
# 423320       3.00    2449.97    3169.69  182.350989  ...        False  37.0
# 423321     582.74    5797.47    1514.93  182.350989  ...        False  37.0
# 423322      85.72     744.84    2150.36  182.350989  ...        False  37.0
# 423323     204.19     363.00    1059.46  182.350989  ...        False  37.0
# 423324       2.06      10.88    1864.57  182.350989  ...        False  37.0
#
#         weekly_sales  isholiday_y type      size   revenue       cost  \
# 0           24924.50        False    A  151315.0  24924.50  17447.150
# 1           50605.27        False    A  151315.0  50605.27  35423.689
# 2           13740.12        False    A  151315.0  13740.12   9618.084
# 3           39954.04        False    A  151315.0  39954.04  27967.828
# 4           32229.38        False    A  151315.0  32229.38  22560.566
# ...              ...          ...  ...       ...       ...        ...
# 423320       7612.03          NaN  NaN  140167.0   7612.03   5328.421
# 423321       7612.03          NaN  NaN  140167.0   7612.03   5328.421
# 423322       7612.03          NaN  NaN  140167.0   7612.03   5328.421
# 423323       7612.03          NaN  NaN  140167.0   7612.03   5328.421
# 423324       7612.03          NaN  NaN  140167.0   7612.03   5328.421
#
#            profit    month
# 0        7477.350  2010-02
# 1       15181.581  2010-02
# 2        4122.036  2010-02
# 3       11986.212  2010-02
# 4        9668.814  2010-02
# ...           ...      ...
# 423320   2283.609  2013-06
# 423321   2283.609  2013-07
# 423322   2283.609  2013-07
# 423323   2283.609  2013-07
# 423324   2283.609  2013-07
#
# [423325 rows x 21 columns]

# %% [markdown]
# #**LOAD**

# %%
monthly_summary = df_full.groupby(['store','dept','month']).agg({
    'weekly_sales':'sum',
    'revenue':'sum',
    'profit':'sum'
}).reset_index()

# %%
monthly_summary.to_csv("monthly_sales.csv",index=False)
